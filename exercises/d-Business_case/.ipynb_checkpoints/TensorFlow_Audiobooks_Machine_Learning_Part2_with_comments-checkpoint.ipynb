# %% [markdown]
# # Practical example. Audiobooks

# %% [markdown]
# ## Problem
#
# You are given data from an Audiobook app. Logically, it relates only to the audio versions of books. Each customer in the database has made a purchase at least once, that's why he/she is in the database. We want to create a machine learning algorithm based on our available data that can predict if a customer will buy again from the Audiobook company.
#
# The main idea is that if a customer has a low probability of coming back, there is no reason to spend any money on advertizing to him/her. If we can focus our efforts ONLY on customers that are likely to convert again, we can make great savings. Moreover, this model can identify the most important metrics for a customer to come back again. Identifying new customers creates value and growth opportunities.
#
# You have a .csv summarizing the data. There are several variables: Customer ID, Book length in mins_avg (average of all purchases), Book length in minutes_sum (sum of all purchases), Price Paid_avg (average of all purchases), Price paid_sum (sum of all purchases), Review (a Boolean variable), Review (out of 10), Total minutes listened, Completion (from 0 to 1), Support requests (number), and Last visited minus purchase date (in days).
#
# So these are the inputs (excluding customer ID, as it is completely arbitrary. It's more like a name, than a number).
#
# The targets are a Boolean variable (so 0, or 1). We are taking a period of 2 years in our inputs, and the next 6 months as targets. So, in fact, we are predicting if: based on the last 2 years of activity and engagement, a customer will convert in the next 6 months. 6 months sounds like a reasonable time. If they don't convert after 6 months, chances are they've gone to a competitor or didn't like the Audiobook way of digesting information.
#
# The task is simple: create a machine learning algorithm, which is able to predict if a customer will buy again.
#
# This is a classification problem with two classes: won't buy and will buy, represented by 0s and 1s.
#
# Good luck!

# %% [markdown]
# ## Create the machine learning algorithm

# %% [markdown]
# ### Import the relevant libraries

# %%
# we must import the libraries once again since we haven't imported them in this file
import numpy as np
import tensorflow as tf

# %% [markdown]
# ### Data

# %%
# let's create a temporary variable npz, where we will store each of the three Audiobooks datasets
npz = np.load('Audiobooks_data_train.npz')

# we extract the inputs using the keyword under which we saved them
# to ensure that they are all floats, let's also take care of that
train_inputs = npz['inputs'].astype(np.float)
# targets must be int because of sparse_categorical_crossentropy (we want to be able to smoothly one-hot encode them)
train_targets = npz['targets'].astype(np.int)

# we load the validation data in the temporary variable
npz = np.load('Audiobooks_data_validation.npz')
# we can load the inputs and the targets in the same line
validation_inputs, validation_targets = npz['inputs'].astype(np.float), npz['targets'].astype(np.int)

# we load the test data in the temporary variable
npz = np.load('Audiobooks_data_test.npz')
# we create 2 variables that will contain the test inputs and the test targets
test_inputs, test_targets = npz['inputs'].astype(np.float), npz['targets'].astype(np.int)

# %% [markdown]
# ### Model
# Outline, optimizers, loss, early stopping and training

# %%
# Set the input and output sizes
input_size = 10
output_size = 2
# Use same hidden layer size for both hidden layers. Not a necessity.
hidden_layer_size = 50
    
# define how the model will look like
model = tf.keras.Sequential([
    # tf.keras.layers.Dense is basically implementing: output = activation(dot(input, weight) + bias)
    # it takes several arguments, but the most important ones for us are the hidden_layer_size and the activation function
    tf.keras.layers.Dense(hidden_layer_size, activation='relu'), # 1st hidden layer
    tf.keras.layers.Dense(hidden_layer_size, activation='relu'), # 2nd hidden layer
    # the final layer is no different, we just make sure to activate it with softmax
    tf.keras.layers.Dense(output_size, activation='softmax') # output layer
])


### Choose the optimizer and the loss function

# we define the optimizer we'd like to use, 
# the loss function, 
# and the metrics we are interested in obtaining at each iteration
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

### Training
# That's where we train the model we have built.

# set the batch size
batch_size = 100

# set a maximum number of training epochs
max_epochs = 100


# fit the model
# note that this time the train, validation and test data are not iterable
model.fit(train_inputs, # train inputs
          train_targets, # train targets
          batch_size=batch_size, # batch size
          epochs=max_epochs, # epochs that we will train for (assuming early stopping doesn't kick in)
          validation_data=(validation_inputs, validation_targets), # validation data
          verbose = 2 # making sure we get enough information about the training process
          )
# Out:
# Train on 3579 samples, validate on 447 samples
# Epoch 1/100
# 3579/3579 - 0s - loss: 0.5366 - accuracy: 0.7902 - val_loss: 0.4098 - val_accuracy: 0.8881
# Epoch 2/100
# 3579/3579 - 0s - loss: 0.3537 - accuracy: 0.8821 - val_loss: 0.3241 - val_accuracy: 0.8837
# Epoch 3/100
# 3579/3579 - 0s - loss: 0.3089 - accuracy: 0.8849 - val_loss: 0.3046 - val_accuracy: 0.8859
# Epoch 4/100
# 3579/3579 - 0s - loss: 0.2928 - accuracy: 0.8905 - val_loss: 0.2945 - val_accuracy: 0.8949
# Epoch 5/100
# 3579/3579 - 0s - loss: 0.2809 - accuracy: 0.8941 - val_loss: 0.2866 - val_accuracy: 0.8949
# Epoch 6/100
# 3579/3579 - 0s - loss: 0.2712 - accuracy: 0.8969 - val_loss: 0.2834 - val_accuracy: 0.8859
# Epoch 7/100
# 3579/3579 - 0s - loss: 0.2670 - accuracy: 0.8986 - val_loss: 0.2753 - val_accuracy: 0.8949
# Epoch 8/100
# 3579/3579 - 0s - loss: 0.2617 - accuracy: 0.8994 - val_loss: 0.2730 - val_accuracy: 0.8971
# Epoch 9/100
# 3579/3579 - 0s - loss: 0.2567 - accuracy: 0.9000 - val_loss: 0.2720 - val_accuracy: 0.8971
# Epoch 10/100
# 3579/3579 - 0s - loss: 0.2547 - accuracy: 0.9019 - val_loss: 0.2718 - val_accuracy: 0.8971
# Epoch 11/100
# 3579/3579 - 0s - loss: 0.2489 - accuracy: 0.9036 - val_loss: 0.2630 - val_accuracy: 0.9016
# Epoch 12/100
# 3579/3579 - 0s - loss: 0.2474 - accuracy: 0.9033 - val_loss: 0.2632 - val_accuracy: 0.9038
# Epoch 13/100
# 3579/3579 - 0s - loss: 0.2447 - accuracy: 0.9047 - val_loss: 0.2635 - val_accuracy: 0.9038
# Epoch 14/100
# 3579/3579 - 0s - loss: 0.2433 - accuracy: 0.9042 - val_loss: 0.2628 - val_accuracy: 0.9038
# Epoch 15/100
# 3579/3579 - 0s - loss: 0.2409 - accuracy: 0.9072 - val_loss: 0.2603 - val_accuracy: 0.9038
# Epoch 16/100
# 3579/3579 - 0s - loss: 0.2398 - accuracy: 0.9081 - val_loss: 0.2550 - val_accuracy: 0.9038
# Epoch 17/100
# 3579/3579 - 0s - loss: 0.2367 - accuracy: 0.9078 - val_loss: 0.2598 - val_accuracy: 0.9060
# Epoch 18/100
# 3579/3579 - 0s - loss: 0.2361 - accuracy: 0.9081 - val_loss: 0.2524 - val_accuracy: 0.9105
# Epoch 19/100
# 3579/3579 - 0s - loss: 0.2364 - accuracy: 0.9089 - val_loss: 0.2636 - val_accuracy: 0.8993
# Epoch 20/100
# 3579/3579 - 0s - loss: 0.2361 - accuracy: 0.9067 - val_loss: 0.2529 - val_accuracy: 0.9083
# Epoch 21/100
# 3579/3579 - 0s - loss: 0.2347 - accuracy: 0.9103 - val_loss: 0.2561 - val_accuracy: 0.9038
# Epoch 22/100
# 3579/3579 - 0s - loss: 0.2325 - accuracy: 0.9111 - val_loss: 0.2549 - val_accuracy: 0.9128
# Epoch 23/100
# 3579/3579 - 0s - loss: 0.2329 - accuracy: 0.9103 - val_loss: 0.2500 - val_accuracy: 0.9083
# Epoch 24/100
# 3579/3579 - 0s - loss: 0.2316 - accuracy: 0.9103 - val_loss: 0.2536 - val_accuracy: 0.9083
# Epoch 25/100
# 3579/3579 - 0s - loss: 0.2322 - accuracy: 0.9125 - val_loss: 0.2548 - val_accuracy: 0.9083
# Epoch 26/100
# 3579/3579 - 0s - loss: 0.2285 - accuracy: 0.9109 - val_loss: 0.2593 - val_accuracy: 0.9060
# Epoch 27/100
# 3579/3579 - 0s - loss: 0.2282 - accuracy: 0.9134 - val_loss: 0.2507 - val_accuracy: 0.9060
# Epoch 28/100
# 3579/3579 - 0s - loss: 0.2269 - accuracy: 0.9139 - val_loss: 0.2496 - val_accuracy: 0.9105
# Epoch 29/100
# 3579/3579 - 0s - loss: 0.2249 - accuracy: 0.9131 - val_loss: 0.2471 - val_accuracy: 0.9083
# Epoch 30/100
# 3579/3579 - 0s - loss: 0.2251 - accuracy: 0.9142 - val_loss: 0.2475 - val_accuracy: 0.9083
# Epoch 31/100
# 3579/3579 - 0s - loss: 0.2252 - accuracy: 0.9139 - val_loss: 0.2464 - val_accuracy: 0.9105
# Epoch 32/100
# 3579/3579 - 0s - loss: 0.2261 - accuracy: 0.9139 - val_loss: 0.2463 - val_accuracy: 0.9083
# Epoch 33/100
# 3579/3579 - 0s - loss: 0.2235 - accuracy: 0.9148 - val_loss: 0.2462 - val_accuracy: 0.9083
# Epoch 34/100
# 3579/3579 - 0s - loss: 0.2234 - accuracy: 0.9151 - val_loss: 0.2430 - val_accuracy: 0.9105
# Epoch 35/100
# 3579/3579 - 0s - loss: 0.2226 - accuracy: 0.9137 - val_loss: 0.2459 - val_accuracy: 0.9105
# Epoch 36/100
# 3579/3579 - 0s - loss: 0.2243 - accuracy: 0.9142 - val_loss: 0.2434 - val_accuracy: 0.9083
# Epoch 37/100
# 3579/3579 - 0s - loss: 0.2238 - accuracy: 0.9148 - val_loss: 0.2441 - val_accuracy: 0.9083
# Epoch 38/100
# 3579/3579 - 0s - loss: 0.2223 - accuracy: 0.9153 - val_loss: 0.2525 - val_accuracy: 0.9060
# Epoch 39/100
# 3579/3579 - 0s - loss: 0.2221 - accuracy: 0.9151 - val_loss: 0.2478 - val_accuracy: 0.9060
# Epoch 40/100
# 3579/3579 - 0s - loss: 0.2208 - accuracy: 0.9173 - val_loss: 0.2567 - val_accuracy: 0.9016
# Epoch 41/100
# 3579/3579 - 0s - loss: 0.2239 - accuracy: 0.9134 - val_loss: 0.2433 - val_accuracy: 0.9105
# Epoch 42/100
# 3579/3579 - 0s - loss: 0.2226 - accuracy: 0.9148 - val_loss: 0.2472 - val_accuracy: 0.9105
# Epoch 43/100
# 3579/3579 - 0s - loss: 0.2197 - accuracy: 0.9176 - val_loss: 0.2457 - val_accuracy: 0.9105
# Epoch 44/100
# 3579/3579 - 0s - loss: 0.2210 - accuracy: 0.9165 - val_loss: 0.2513 - val_accuracy: 0.9060
# Epoch 45/100
# 3579/3579 - 0s - loss: 0.2214 - accuracy: 0.9145 - val_loss: 0.2465 - val_accuracy: 0.9105
# Epoch 46/100
# 3579/3579 - 0s - loss: 0.2193 - accuracy: 0.9159 - val_loss: 0.2453 - val_accuracy: 0.9083
# Epoch 47/100
# 3579/3579 - 0s - loss: 0.2179 - accuracy: 0.9162 - val_loss: 0.2439 - val_accuracy: 0.9172
# Epoch 48/100
# 3579/3579 - 0s - loss: 0.2201 - accuracy: 0.9156 - val_loss: 0.2424 - val_accuracy: 0.9105
# Epoch 49/100
# 3579/3579 - 0s - loss: 0.2192 - accuracy: 0.9176 - val_loss: 0.2504 - val_accuracy: 0.9105
# Epoch 50/100
# 3579/3579 - 0s - loss: 0.2179 - accuracy: 0.9165 - val_loss: 0.2442 - val_accuracy: 0.9128
# Epoch 51/100
# 3579/3579 - 0s - loss: 0.2179 - accuracy: 0.9148 - val_loss: 0.2432 - val_accuracy: 0.9083
# Epoch 52/100
# 3579/3579 - 0s - loss: 0.2163 - accuracy: 0.9176 - val_loss: 0.2389 - val_accuracy: 0.9105
# Epoch 53/100
# 3579/3579 - 0s - loss: 0.2181 - accuracy: 0.9173 - val_loss: 0.2465 - val_accuracy: 0.9038
# Epoch 54/100
# 3579/3579 - 0s - loss: 0.2167 - accuracy: 0.9167 - val_loss: 0.2442 - val_accuracy: 0.9083
# Epoch 55/100
# 3579/3579 - 0s - loss: 0.2160 - accuracy: 0.9173 - val_loss: 0.2435 - val_accuracy: 0.9105
# Epoch 56/100
# 3579/3579 - 0s - loss: 0.2146 - accuracy: 0.9167 - val_loss: 0.2443 - val_accuracy: 0.9128
# Epoch 57/100
# 3579/3579 - 0s - loss: 0.2174 - accuracy: 0.9134 - val_loss: 0.2471 - val_accuracy: 0.9083
# Epoch 58/100
# 3579/3579 - 0s - loss: 0.2135 - accuracy: 0.9195 - val_loss: 0.2505 - val_accuracy: 0.9172
# Epoch 59/100
# 3579/3579 - 0s - loss: 0.2169 - accuracy: 0.9176 - val_loss: 0.2516 - val_accuracy: 0.9105
# Epoch 60/100
# 3579/3579 - 0s - loss: 0.2183 - accuracy: 0.9153 - val_loss: 0.2432 - val_accuracy: 0.9105
# Epoch 61/100
# 3579/3579 - 0s - loss: 0.2138 - accuracy: 0.9173 - val_loss: 0.2450 - val_accuracy: 0.9105
# Epoch 62/100
# 3579/3579 - 0s - loss: 0.2139 - accuracy: 0.9159 - val_loss: 0.2411 - val_accuracy: 0.9128
# Epoch 63/100
# 3579/3579 - 0s - loss: 0.2151 - accuracy: 0.9170 - val_loss: 0.2457 - val_accuracy: 0.9105
# Epoch 64/100
# 3579/3579 - 0s - loss: 0.2150 - accuracy: 0.9173 - val_loss: 0.2425 - val_accuracy: 0.9128
# Epoch 65/100
# 3579/3579 - 0s - loss: 0.2151 - accuracy: 0.9190 - val_loss: 0.2428 - val_accuracy: 0.9105
# Epoch 66/100
# 3579/3579 - 0s - loss: 0.2132 - accuracy: 0.9179 - val_loss: 0.2436 - val_accuracy: 0.9105
# Epoch 67/100
# 3579/3579 - 0s - loss: 0.2117 - accuracy: 0.9195 - val_loss: 0.2567 - val_accuracy: 0.9105
# Epoch 68/100
# 3579/3579 - 0s - loss: 0.2122 - accuracy: 0.9173 - val_loss: 0.2463 - val_accuracy: 0.9128
# Epoch 69/100
# 3579/3579 - 0s - loss: 0.2123 - accuracy: 0.9179 - val_loss: 0.2417 - val_accuracy: 0.9105
# Epoch 70/100
# 3579/3579 - 0s - loss: 0.2134 - accuracy: 0.9181 - val_loss: 0.2370 - val_accuracy: 0.9150
# Epoch 71/100
# 3579/3579 - 0s - loss: 0.2120 - accuracy: 0.9184 - val_loss: 0.2487 - val_accuracy: 0.9083
# Epoch 72/100
# 3579/3579 - 0s - loss: 0.2099 - accuracy: 0.9176 - val_loss: 0.2429 - val_accuracy: 0.9105
# Epoch 73/100
# 3579/3579 - 0s - loss: 0.2122 - accuracy: 0.9159 - val_loss: 0.2519 - val_accuracy: 0.8971
# Epoch 74/100
# 3579/3579 - 0s - loss: 0.2141 - accuracy: 0.9167 - val_loss: 0.2633 - val_accuracy: 0.9105
# Epoch 75/100
# 3579/3579 - 0s - loss: 0.2140 - accuracy: 0.9179 - val_loss: 0.2464 - val_accuracy: 0.9105
# Epoch 76/100
# 3579/3579 - 0s - loss: 0.2111 - accuracy: 0.9184 - val_loss: 0.2410 - val_accuracy: 0.9105
# Epoch 77/100
# 3579/3579 - 0s - loss: 0.2122 - accuracy: 0.9195 - val_loss: 0.2484 - val_accuracy: 0.9083
# Epoch 78/100
# 3579/3579 - 0s - loss: 0.2126 - accuracy: 0.9173 - val_loss: 0.2411 - val_accuracy: 0.9128
# Epoch 79/100
# 3579/3579 - 0s - loss: 0.2121 - accuracy: 0.9190 - val_loss: 0.2423 - val_accuracy: 0.9105
# Epoch 80/100
# 3579/3579 - 0s - loss: 0.2123 - accuracy: 0.9181 - val_loss: 0.2397 - val_accuracy: 0.9150
# Epoch 81/100
# 3579/3579 - 0s - loss: 0.2112 - accuracy: 0.9195 - val_loss: 0.2477 - val_accuracy: 0.9150
# Epoch 82/100
# 3579/3579 - 0s - loss: 0.2123 - accuracy: 0.9165 - val_loss: 0.2458 - val_accuracy: 0.9060
# Epoch 83/100
# 3579/3579 - 0s - loss: 0.2104 - accuracy: 0.9187 - val_loss: 0.2473 - val_accuracy: 0.9105
# Epoch 84/100
# 3579/3579 - 0s - loss: 0.2085 - accuracy: 0.9198 - val_loss: 0.2396 - val_accuracy: 0.9105
# Epoch 85/100
# 3579/3579 - 0s - loss: 0.2119 - accuracy: 0.9193 - val_loss: 0.2479 - val_accuracy: 0.9128
# Epoch 86/100
# 3579/3579 - 0s - loss: 0.2092 - accuracy: 0.9206 - val_loss: 0.2468 - val_accuracy: 0.9150
# Epoch 87/100
# 3579/3579 - 0s - loss: 0.2094 - accuracy: 0.9187 - val_loss: 0.2460 - val_accuracy: 0.9128
# Epoch 88/100
# 3579/3579 - 0s - loss: 0.2100 - accuracy: 0.9209 - val_loss: 0.2448 - val_accuracy: 0.9083
# Epoch 89/100
# 3579/3579 - 0s - loss: 0.2109 - accuracy: 0.9193 - val_loss: 0.2416 - val_accuracy: 0.9105
# Epoch 90/100
# 3579/3579 - 0s - loss: 0.2089 - accuracy: 0.9190 - val_loss: 0.2407 - val_accuracy: 0.9128
# Epoch 91/100
# 3579/3579 - 0s - loss: 0.2104 - accuracy: 0.9206 - val_loss: 0.2505 - val_accuracy: 0.9038
# Epoch 92/100
# 3579/3579 - 0s - loss: 0.2108 - accuracy: 0.9173 - val_loss: 0.2480 - val_accuracy: 0.9083
# Epoch 93/100
# 3579/3579 - 0s - loss: 0.2093 - accuracy: 0.9179 - val_loss: 0.2424 - val_accuracy: 0.9128
# Epoch 94/100
# 3579/3579 - 0s - loss: 0.2076 - accuracy: 0.9206 - val_loss: 0.2449 - val_accuracy: 0.9038
# Epoch 95/100
# 3579/3579 - 0s - loss: 0.2094 - accuracy: 0.9209 - val_loss: 0.2445 - val_accuracy: 0.9128
# Epoch 96/100
# 3579/3579 - 0s - loss: 0.2094 - accuracy: 0.9179 - val_loss: 0.2428 - val_accuracy: 0.9128
# Epoch 97/100
# 3579/3579 - 0s - loss: 0.2106 - accuracy: 0.9195 - val_loss: 0.2434 - val_accuracy: 0.9195
# Epoch 98/100
# 3579/3579 - 0s - loss: 0.2141 - accuracy: 0.9179 - val_loss: 0.2451 - val_accuracy: 0.9128
# Epoch 99/100
# 3579/3579 - 0s - loss: 0.2105 - accuracy: 0.9190 - val_loss: 0.2532 - val_accuracy: 0.9016
# Epoch 100/100
# 3579/3579 - 0s - loss: 0.2092 - accuracy: 0.9179 - val_loss: 0.2378 - val_accuracy: 0.9128
